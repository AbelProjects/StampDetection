# %%
import os
import sys
from pathlib import Path

# %%
relative_path = ''
folder_name = 'check_creation'
folder_path = os.path.join(os.path.abspath(relative_path),folder_name)

# %%
Path(folder_path).mkdir(parents=True, exist_ok=True)

# %%
Path().mkdir()

# %%
from pathlib import Path
from IPython.display import clear_output
relative_dir_path = '../data/color/pdf_docs'
abs_dir_path = os.path.abspath(relative_dir_path)
pathlist = Path(abs_dir_path).rglob('*.pdf')
for doc in pathlist:
    doc_name = str(doc).split(os.sep)[-1]
    print(doc_name)
# Out:
# 2017-09-25_Письмо ООО_Шушарес.pdf
# 2017-10-09_АО Новая ЭРА.pdf
# 2017-10-12_ООО «Сою-з» (Андрей Майоров).pdf
# 2017-11-15_ООО ГЛК Холдоми.pdf
# 2017-11-15_ООО Экстрим Сервис.pdf
# 2017-12-08_ООО Динас.pdf
# 2016-12-01_ООО Альтернативная энергетика.pdf
# 2017-11-20_ООО Молоко Приморья.pdf
# 2017-03-15_Инвест Индия.pdf
# 2017-11-10_ООО Космос Групп, ООО Сегежа Групп, АО КРДВ, Правительство Сахалинской области.pdf
# 2017-07-09 Письмо ООО-Аквафиш (1).pdf
# 2017-12-15_Институт георгафических наук.pdf
# 2017-12-17_Амурагроцентр.pdf
# 2017-11-22_ООО «Кангаус» (Андрей МАЙОРОВ).pdf
# 2017-09-12_JGC Corporation, Hokuto Social Medical Corporation.pdf
# 2017-10-05_ООО Эвентус.pdf
# 2017-05-02_Neft Beverages.pdf
# 2017-04-06_АО РНГ.pdf
# 2016-11-10_ООО Смарт Кэпитал.pdf
# 2017-09-06_Корпорация KT, Госпиталь Пусанского университета.pdf
# 2017-11-23_ООО УК АЯМ.pdf
# 2017-06-20_Письмо ООО Отель Прайд.pdf
# 2016-10-10_ООО Красный Вымпел.pdf
# 2017-12-01_ДальСТАМ.pdf
# ...

# %%
import shutil

# %%
file_source = str(doc)
file_name = str(doc).split(os.sep)[-1]
file_dst = os.path.join(os.path.abspath(''),file_name)

# %%
shutil.copyfile(src = file_source, dst = file_dst)
# Out:
# '/Users/belyakov/Desktop/StampRecognition/StampDetection/notebooks/2017-09-22_ООО НГК Ресурс.pdf'

# %%
file_source = os.path.join(os.path.abspath(''),file_name)
file_dst = os.path.join(os.path.abspath('./check_creation'), file_name)
shutil.move(file_source, file_dst)
# Out:
# '/Users/belyakov/Desktop/StampRecognition/StampDetection/notebooks/check_creation/2017-09-22_ООО НГК Ресурс.pdf'

# %%
file_dst
# Out:
# '/Users/belyakov/Desktop/StampRecognition/StampDetection/notebooks/check_creation/2017-09-22_ООО НГК Ресурс.pdf'

# %%
b = False
a = 5 if b else 2

# %%
a
# Out:
# 2

# %%
def f():
    print('Yes')

# %%
f() if b else pass
# Out:
#   Input In [39]
#     f() if b else pass
#                   ^
# SyntaxError: invalid syntax
